# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

incomes = np.random.normal(27000, 15000, 10000)

# %%
incomes_1 = np.append(incomes, [10000000, 9999999])
incomes_1[-5:]
# Out:
# array([   28468.34038006,    33431.28116305,    29663.17175973,
#        10000000.        ,  9999999.        ])

# %%
plt.hist(incomes, 60)
plt.show()

# %%
plt.hist(incomes_1, 50)
plt.show()
